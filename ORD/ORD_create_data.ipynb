# %% [markdown]
# # ORD/data 폴더에 이름에 맞게 데이터 셋 구성

# %% [markdown]
# ## 불균형 데이터 및 테스트 데이터 생성

# %%
# !python preprocess.py --dataname adult --testsize 4000 --imbalance_ratio 0.02 --target income
# !python preprocess.py --dataname cardio --testsize 4000 --imbalance_ratio 0.02 --target income
# !python preprocess.py --dataname fintech --testsize 4000 --imbalance_ratio 0.02 --target income
# !python preprocess.py --dataname heloc --testsize 2000 --imbalance_ratio 0.02 --target income

# %% [markdown]
# ## ORD 데이터 생성

# %%
# !python detect_overlap.py --dataname adult --target income --threshold 0.3
# !python detect_overlap.py --dataname cardio --target income --threshold 0.3
# !python detect_overlap.py --dataname fintech --target income --threshold 0.3
# !python detect_overlap.py --dataname heloc --target income --threshold 0.3
