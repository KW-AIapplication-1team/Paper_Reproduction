# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install sdmetrics==0.14.1
# Out:
# Requirement already satisfied: sdmetrics==0.14.1 in /usr/local/lib/python3.12/dist-packages (0.14.1)
# Requirement already satisfied: copulas>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from sdmetrics==0.14.1) (0.12.3)
# Requirement already satisfied: tqdm>=4.29 in /usr/local/lib/python3.12/dist-packages (from sdmetrics==0.14.1) (4.67.1)
# Requirement already satisfied: plotly>=5.19.0 in /usr/local/lib/python3.12/dist-packages (from sdmetrics==0.14.1) (5.24.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from sdmetrics==0.14.1) (2.0.0)
# Requirement already satisfied: pandas>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from sdmetrics==0.14.1) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from sdmetrics==0.14.1) (1.5.0)
# Requirement already satisfied: scipy>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from sdmetrics==0.14.1) (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->sdmetrics==0.14.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->sdmetrics==0.14.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.1.1->sdmetrics==0.14.1) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly>=5.19.0->sdmetrics==0.14.1) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly>=5.19.0->sdmetrics==0.14.1) (25.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->sdmetrics==0.14.1) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.1->sdmetrics==0.14.1) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1.1->sdmetrics==0.14.1) (1.17.0)

# %%
# %cd /content/drive/MyDrive/ORD
# Out:
# /content/drive/MyDrive/ORD

# %% [markdown]
# # ORD 성능 측정

# %%
import warnings
from sklearn.exceptions import ConvergenceWarning

print("adult"+"="*30)
# !python compute_mle.py --dataname adult --target income --method tabsyn
print("cardio"+"="*30)
# !python compute_mle.py --dataname cardio --target cardio --method tabsyn
print("fintech"+"="*30)
# !python compute_mle.py --dataname fintech --target churn --method tabsyn
print("heloc"+"="*30)
# !python compute_mle.py --dataname heloc --target is_at_risk --method tabsyn
print("성능측정 완료")
# Out:
# adult==============================
# 2038
# XG:  80.4
# Minority class accuracy:  81.35
# Majority class accuracy:  79.45
# Fraction of true: 0.804
# ECE  [0.04055099]
# Figure(640x480)
# Figure(640x480)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Scores -
# ada: 0.812960235640648,
# dt: 0.805875152998776,
# lr: 0.7818228763232636,
# mlp: 0.798992443324937
# avg: 0.7999126770719062
# 2055
# XG:  81.375
# Minority class accuracy:  82.75
# Majority class accuracy:  80.0
# Fraction of true: 0.81375
# ECE  [0.03139633]
# Figure(640x480)
# Figure(640x480)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Scores -
# ada: 0.8191227205519961,
# dt: 0.8056502679006332,
# lr: 0.7776904948939513,
# mlp: 0.82275390625
# avg: 0.8063043473991451
# cardio==============================
# 1938
# XG:  72.5
# Minority class accuracy:  70.95
# Majority class accuracy:  74.05000000000001
# Fraction of true: 0.725
# ECE  [0.02517672]
# Figure(640x480)
# Figure(640x480)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Scores -
# ada: 0.7176906779661016,
# dt: 0.6947903430749682,
# lr: 0.6510430079835179,
# mlp: 0.72998712998713
# avg: 0.6983777897529294
# 1921
# XG:  72.02499999999999
# Minority class accuracy:  70.05
# Majority class accuracy:  74.0
# Fraction of true: 0.72025
# ECE  [0.01576225]
# Figure(640x480)
# Figure(640x480)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Scores -
# ada: 0.7127175368139224,
# dt: 0.6926677067082684,
# lr: 0.7128611608284326,
# mlp: 0.7273199896022875
# avg: 0.7113915984882277
# fintech==============================
# 2035
# XG:  64.025
# Minority class accuracy:  64.9
# Majority class accuracy:  63.14999999999999
# Fraction of true: 0.64025
# ECE  [0.07150563]
# Figure(640x480)
# Figure(640x480)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Scores -
# ada: 0.6695402298850575,
# dt: 0.5916981132075472,
# lr: 0.6801710555930678,
# mlp: 0.6673137587964086
# avg: 0.6521807893705203
# 2026
# XG:  64.55
# Minority class accuracy:  65.2
# Majority class accuracy:  63.9
# Fraction of true: 0.6455
# ECE  [0.05644314]
# Figure(640x480)
# Figure(640x480)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Scores -
# ada: 0.6787564766839378,
# dt: 0.596,
# lr: 0.6794471689701292,
# mlp: 0.6742552676192782
# avg: 0.6571147283183363
# heloc==============================
# 774
# XG:  63.5
# Minority class accuracy:  52.2
# Majority class accuracy:  74.8
# Fraction of true: 0.635
# ECE  [0.20076889]
# Figure(640x480)
# Figure(640x480)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Scores -
# ada: 0.6565285789197692,
# dt: 0.6218144750254841,
# lr: 0.6983967935871743,
# mlp: 0.6382978723404256
# avg: 0.6537594299682132
# 935
# XG:  65.45
# Minority class accuracy:  62.2
# Majority class accuracy:  68.7
# Fraction of true: 0.6545
# ECE  [0.17705249]
# Figure(640x480)
# Figure(640x480)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Scores -
# ada: 0.6877828054298643,
# dt: 0.6279185295578739,
# lr: 0.6842105263157895,
# mlp: 0.6819571865443425
# avg: 0.6704672619619675
# 성능측정 완료

# %% [markdown]
# # basic model

# %%
import os, glob, warnings
import numpy as np
import pandas as pd

from sklearn.exceptions import ConvergenceWarning
warnings.filterwarnings("ignore", category=ConvergenceWarning)  # LR/MLP 수렴 경고 숨김
warnings.filterwarnings("ignore", category=UserWarning)

from sklearn.metrics import accuracy_score, recall_score, roc_auc_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.neural_network import MLPClassifier

# XGBoost (있으면 사용)
try:
    from xgboost import XGBClassifier
    HAS_XGB = True
except Exception:
    HAS_XGB = False
    print("⚠️ xgboost not available. Skipping XGB baseline.")


# ---- Metrics ----
def expected_calibration_error_binary(p_pos: np.ndarray, y_true: np.ndarray, M: int = 10):
    p_pos = np.asarray(p_pos).reshape(-1)
    y_true = np.asarray(y_true).reshape(-1).astype(int)

    bin_edges = np.linspace(0.0, 1.0, M + 1)
    ece = 0.0
    for i in range(M):
        lo, hi = bin_edges[i], bin_edges[i + 1]
        in_bin = (p_pos > lo) & (p_pos <= hi)
        if not np.any(in_bin):
            continue
        acc = (((p_pos[in_bin] >= 0.5).astype(int) == y_true[in_bin]).mean())
        conf = p_pos[in_bin].mean()
        ece += np.abs(acc - conf) * in_bin.mean()
    return float(ece)

def minority_majority_recall(y_true, y_pred):
    y_true = np.asarray(y_true).astype(int)
    y_pred = np.asarray(y_pred).astype(int)
    rec_min = recall_score(y_true, y_pred, pos_label=1)
    rec_maj = recall_score(y_true, y_pred, pos_label=0)
    return float(rec_min), float(rec_maj)


# ---- Target inference ----
COMMON_TARGET_NAMES = ["income","cardio","churn","is_at_risk"]

def infer_target_column(df: pd.DataFrame, user_target=None):
    if user_target and user_target in df.columns:
        return user_target
    for c in COMMON_TARGET_NAMES:
        if c in df.columns:
            return c
    return df.columns[-1]  # fallback


# ---- Preprocessor ----
def build_preprocessor(X: pd.DataFrame):
    cat_cols = [c for c in X.columns if X[c].dtype == "object" or str(X[c].dtype).startswith("category")]
    num_cols = [c for c in X.columns if c not in cat_cols]

    pre = ColumnTransformer(
        transformers=[
            ("num", StandardScaler(), num_cols),
            ("cat", OneHotEncoder(handle_unknown="ignore", sparse_output=True), cat_cols),
        ],
        remainder="drop",
        sparse_threshold=0.3
    )
    return pre


# ---- Models ----
def get_models(random_state=42):
    models = {
        "LR": LogisticRegression(max_iter=2000),
        "DT": DecisionTreeClassifier(random_state=random_state),
        "ADA": AdaBoostClassifier(random_state=random_state),
        "RF": RandomForestClassifier(n_estimators=300, random_state=random_state, n_jobs=-1),
        "MLP": MLPClassifier(hidden_layer_sizes=(128,64), max_iter=500, random_state=random_state),
    }
    if HAS_XGB:
        models["XGB"] = XGBClassifier(
            n_estimators=400,
            max_depth=6,
            learning_rate=0.05,
            subsample=0.9,
            colsample_bytree=0.9,
            reg_lambda=1.0,
            random_state=random_state,
            n_jobs=-1,
            eval_metric="logloss",
        )
    return models


def fit_predict_proba(pipe: Pipeline, X_train, y_train, X_test):
    pipe.fit(X_train, y_train)
    if hasattr(pipe, "predict_proba"):
        return pipe.predict_proba(X_test)[:, 1]
    # fallback
    scores = pipe.decision_function(X_test)
    return 1 / (1 + np.exp(-scores))

# %%
DATA_ROOT = "/content/drive/MyDrive/ORD/data"
TRAIN_FILE = "imbalanced_noord.csv"
TEST_FILE  = "test.csv"
USER_TARGET = None                 # ex) "income"처럼 고정하고 싶으면 여기 넣어

random_state = 42
models = get_models(random_state=random_state)

dataset_dirs = sorted([p for p in glob.glob(os.path.join(DATA_ROOT, "*")) if os.path.isdir(p)])

all_rows = []
for d in dataset_dirs:
    train_path = os.path.join(d, TRAIN_FILE)
    test_path  = os.path.join(d, TEST_FILE)
    if not (os.path.exists(train_path) and os.path.exists(test_path)):
        continue

    train_df = pd.read_csv(train_path)
    test_df  = pd.read_csv(test_path)

    target = infer_target_column(train_df, USER_TARGET)
    if target not in test_df.columns:
        # 혹시 test쪽 target명이 다르면 test 기준으로 다시 추론
        target2 = infer_target_column(test_df, USER_TARGET)
        if target2 in train_df.columns:
            target = target2
        else:
            print(f"❌ Skip {os.path.basename(d)}: target mismatch")
            continue

    X_train = train_df.drop(columns=[target])
    y_train = train_df[target].astype(int)

    X_test  = test_df.drop(columns=[target])
    y_test  = test_df[target].astype(int)

    pre = build_preprocessor(X_train)

    print(f"\n=== {os.path.basename(d)} | target={target} | n_train={len(train_df)} n_test={len(test_df)} ===")

    for name, clf in models.items():
        pipe = Pipeline([("pre", pre), ("clf", clf)])
        p_pos = fit_predict_proba(pipe, X_train, y_train, X_test)
        y_pred = (p_pos >= 0.5).astype(int)

        acc = accuracy_score(y_test, y_pred)
        rec_min, rec_maj = minority_majority_recall(y_test, y_pred)
        ece = expected_calibration_error_binary(p_pos, y_test, M=10)
        auroc = roc_auc_score(y_test, p_pos) if len(np.unique(y_test)) == 2 else np.nan

        all_rows.append({
            "dataset": os.path.basename(d),
            "train_file": TRAIN_FILE,
            "test_file": TEST_FILE,
            "target": target,
            "model": name,
            "accuracy": acc,
            "minority_recall(1)": rec_min,
            "majority_recall(0)": rec_maj,
            "auroc": auroc,
            "ece": ece,
            "n_train": len(train_df),
            "n_test": len(test_df),
        })

    # 데이터셋별 요약표
    tmp = pd.DataFrame([r for r in all_rows if r["dataset"] == os.path.basename(d)])
    display(tmp.sort_values("accuracy", ascending=False)[["model","accuracy","minority_recall(1)","majority_recall(0)","auroc","ece"]])

results_df = pd.DataFrame(all_rows)
results_df
# Out:
# === adult | target=income | n_train=32654 n_test=4000 ===
#   model  accuracy  minority_recall(1)  majority_recall(0)     auroc       ece
# 1    DT   0.64075              0.2995              0.9820  0.640750  0.009000
# 5   XGB   0.62775              0.2560              0.9995  0.905801  0.500387
# 3    RF   0.61550              0.2320              0.9990  0.867196  0.202867
# 2   ADA   0.61025              0.2205              1.0000  0.899063  0.133830
# 4   MLP   0.60375              0.2150              0.9925  0.846292  0.487400
# 0    LR   0.55825              0.1170              0.9995  0.889032  0.493379
# === cardio | target=cardio | n_train=33681 n_test=4000 ===
#   model  accuracy  minority_recall(1)  majority_recall(0)     auroc       ece
# 1    DT   0.52050              0.0620               0.979  0.520500  0.010500
# 4   MLP   0.51950              0.0460               0.993  0.599378  0.486870
# 5   XGB   0.50025              0.0005               1.000  0.764662  0.470937
# 2   ADA   0.50025              0.0005               1.000  0.786756  0.020157
# 0    LR   0.50000              0.0000               1.000  0.708857  0.475762
# 3    RF   0.50000              0.0000               1.000  0.751074  0.319592
# === fintech | target=churn | n_train=14098 n_test=4000 ===
#   model  accuracy  minority_recall(1)  majority_recall(0)     auroc       ece
# 1    DT   0.52400              0.0660              0.9820  0.524000  0.009000
# 4   MLP   0.51350              0.0430              0.9840  0.625726  0.492227
# 5   XGB   0.50325              0.0065              1.0000  0.722543  0.482708
# 2   ADA   0.50175              0.0035              1.0000  0.708211  0.027416
# 0    LR   0.50000              0.0000              1.0000  0.695338  0.474595
# 3    RF   0.50000              0.0005              0.9995  0.722340  0.357205
# === heloc | target=is_at_risk | n_train=4080 n_test=2000 ===
#   model  accuracy  minority_recall(1)  majority_recall(0)     auroc       ece
# 1    DT    0.5220               0.062               0.982  0.529439  0.031534
# 4   MLP    0.5115               0.026               0.997  0.618522  0.497660
# 2   ADA    0.5025               0.012               0.993  0.712457  0.035195
# 0    LR    0.5020               0.004               1.000  0.754549  0.468999
# 5   XGB    0.5010               0.004               0.998  0.719404  0.488190
# 3    RF    0.5005               0.001               1.000  0.744776  0.312428
#     dataset            train_file test_file      target model  accuracy  \
# 0     adult  imbalanced_noord.csv  test.csv      income    LR   0.55825
# 1     adult  imbalanced_noord.csv  test.csv      income    DT   0.64075
# 2     adult  imbalanced_noord.csv  test.csv      income   ADA   0.61025
# 3     adult  imbalanced_noord.csv  test.csv      income    RF   0.61550
# 4     adult  imbalanced_noord.csv  test.csv      income   MLP   0.60375
# 5     adult  imbalanced_noord.csv  test.csv      income   XGB   0.62775
# 6    cardio  imbalanced_noord.csv  test.csv      cardio    LR   0.50000
# 7    cardio  imbalanced_noord.csv  test.csv      cardio    DT   0.52050
# 8    cardio  imbalanced_noord.csv  test.csv      cardio   ADA   0.50025
# 9    cardio  imbalanced_noord.csv  test.csv      cardio    RF   0.50000
# 10   cardio  imbalanced_noord.csv  test.csv      cardio   MLP   0.51950
# 11   cardio  imbalanced_noord.csv  test.csv      cardio   XGB   0.50025
# 12  fintech  imbalanced_noord.csv  test.csv       churn    LR   0.50000
# 13  fintech  imbalanced_noord.csv  test.csv       churn    DT   0.52400
# 14  fintech  imbalanced_noord.csv  test.csv       churn   ADA   0.50175
# 15  fintech  imbalanced_noord.csv  test.csv       churn    RF   0.50000
# 16  fintech  imbalanced_noord.csv  test.csv       churn   MLP   0.51350
# 17  fintech  imbalanced_noord.csv  test.csv       churn   XGB   0.50325
# 18    heloc  imbalanced_noord.csv  test.csv  is_at_risk    LR   0.50200
# 19    heloc  imbalanced_noord.csv  test.csv  is_at_risk    DT   0.52200
# 20    heloc  imbalanced_noord.csv  test.csv  is_at_risk   ADA   0.50250
# 21    heloc  imbalanced_noord.csv  test.csv  is_at_risk    RF   0.50050
# 22    heloc  imbalanced_noord.csv  test.csv  is_at_risk   MLP   0.51150
# 23    heloc  imbalanced_noord.csv  test.csv  is_at_risk   XGB   0.50100
#
#     minority_recall(1)  majority_recall(0)     auroc       ece  n_train  \
# 0               0.1170              0.9995  0.889032  0.493379    32654
# 1               0.2995              0.9820  0.640750  0.009000    32654
# 2               0.2205              1.0000  0.899063  0.133830    32654
# 3               0.2320              0.9990  0.867196  0.202867    32654
# 4               0.2150              0.9925  0.846292  0.487400    32654
# 5               0.2560              0.9995  0.905801  0.500387    32654
# 6               0.0000              1.0000  0.708857  0.475762    33681
# 7               0.0620              0.9790  0.520500  0.010500    33681
# 8               0.0005              1.0000  0.786756  0.020157    33681
# 9               0.0000              1.0000  0.751074  0.319592    33681
# 10              0.0460              0.9930  0.599378  0.486870    33681
# 11              0.0005              1.0000  0.764662  0.470937    33681
# 12              0.0000              1.0000  0.695338  0.474595    14098
# 13              0.0660              0.9820  0.524000  0.009000    14098
# 14              0.0035              1.0000  0.708211  0.027416    14098
# 15              0.0005              0.9995  0.722340  0.357205    14098
# 16              0.0430              0.9840  0.625726  0.492227    14098
# 17              0.0065              1.0000  0.722543  0.482708    14098
# 18              0.0040              1.0000  0.754549  0.468999     4080
# 19              0.0620              0.9820  0.529439  0.031534     4080
# 20              0.0120              0.9930  0.712457  0.035195     4080
# 21              0.0010              1.0000  0.744776  0.312428     4080
# 22              0.0260              0.9970  0.618522  0.497660     4080
# 23              0.0040              0.9980  0.719404  0.488190     4080
#
#     n_test
# 0     4000
# 1     4000
# 2     4000
# 3     4000
# 4     4000
# 5     4000
# 6     4000
# 7     4000
# 8     4000
# 9     4000
# 10    4000
# 11    4000
# 12    4000
# 13    4000
# 14    4000
# 15    4000
# 16    4000
# 17    4000
# 18    2000
# 19    2000
# 20    2000
# 21    2000
# 22    2000
# 23    2000
