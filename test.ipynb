# %% [markdown]
# target check

# %% [markdown]
# # adult

# %%
import pandas as pd
adult = pd.read_csv("origin/adult_origin.csv")
heloc = pd.read_csv("origin/heloc_origin.csv")
fintech = pd.read_csv("origin/fintech_origin.csv")
cardio = pd.read_csv("origin/cardio_origin.csv")
abalone = pd.read_csv("origin/abalone_origin.csv")
car = pd.read_csv("origin/car_origin.csv")
bank = pd.read_csv("origin/bank_origin.csv")
heart = pd.read_csv("origin/heart_2020_cleaned_origin.csv")



print(adult.shape)
print(adult['income'].value_counts())

print(heloc.shape)
print(heloc['is_at_risk'].value_counts())

print(fintech.shape)
print(fintech['churn'].value_counts())

print(cardio.shape)
print(cardio['cardio'].value_counts())

print(abalone.shape)
print(abalone['target'].value_counts())

print(bank.shape)
print(bank['y'].value_counts())

print(car.shape)
print(car['target'].value_counts())

print(heart.shape)
print(heart['HeartDisease'].value_counts())
# Out:
# (46443, 14)
# income
# 0    35089
# 1    11354
# Name: count, dtype: int64
# (10459, 24)
# is_at_risk
# 1    5459
# 0    5000
# Name: count, dtype: int64
# (26996, 31)
# churn
# 0    15822
# 1    11174
# Name: count, dtype: int64
# (70000, 13)
# cardio
# 0    35021
# 1    34979
# Name: count, dtype: int64
# (4177, 9)
# target
# 0    3687
# 1     490
# Name: count, dtype: int64
# (45211, 21)
# y
# 0    39922
# 1     5289
# Name: count, dtype: int64
# (1382, 7)
# target
# 0    1324
# 1      58
# Name: count, dtype: int64
# (280875, 21)
# HeartDisease
# 0    253875
# 1     27000
# Name: count, dtype: int64

# %%
import os
for p in os.listdir("origin"):
    df = pd.read_csv(os.path.join("origin", p))
    print(df.isnull().sum().sum() )
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 0

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280875 entries, 0 to 280874
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      280875 non-null  int64
#  1   BMI               280875 non-null  float64
#  2   Smoking           280875 non-null  int64
#  3   AlcoholDrinking   280875 non-null  int64
#  4   Stroke            280875 non-null  int64
#  5   PhysicalHealth    280875 non-null  float64
#  6   MentalHealth      280875 non-null  float64
#  7   DiffWalking       280875 non-null  int64
#  8   Sex               280875 non-null  int64
#  9   AgeCategory       280875 non-null  int64
#  10  Diabetic          280875 non-null  int64
#  11  PhysicalActivity  280875 non-null  int64
#  12  GenHealth         280875 non-null  int64
#  13  Asthma            280875 non-null  int64
#  14  KidneyDisease     280875 non-null  int64
#  15  SkinCancer        280875 non-null  int64
# ...
